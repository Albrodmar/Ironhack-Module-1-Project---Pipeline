# %%
import requests
import pandas as pd
import json

# %%
r = requests.get('https://www.forbes.com/ajax/list/data?year=2018&uri=billionaires&type=person')

# %%
r.json()
pd.read_json
# Out:
# [{'name': 'Abdulsamad Rabiu',
#   'lastName': 'Rabiu',
#   'uri': 'abdulsamad-rabiu',
#   'imageUri': 'abdulsamad-rabiu',
#   'worthChange': 0.0,
#   'age': 59,
#   'source': 'cement, sugar',
#   'industry': 'Diversified',
#   'gender': 'M',
#   'country': 'Nigeria',
#   'timestamp': 1578426901353,
#   'realTimeWorth': 1512.087,
#   'realTimeRank': 1658,
#   'realTimePosition': 1658,
#   'squareImage': '//specials-images.forbesimg.com/imageserve/5c3512ae31358e6b3731fb6e/416x416.jpg?background=000000&cropX1=0&cropX2=744&cropY1=114&cropY2=858'},
#  {'name': 'Adam Kwok',
#   'lastName': 'Kwok',
#   'uri': 'adam-kwok',
#   'imageUri': 'no-pic',
#   'worthChange': -6.891,
#   'age': 36,
#   'source': 'real estate',
#   'industry': 'Real Estate',
#   'gender': 'M',
#   'country': 'Hong Kong',
#   'timestamp': 1578426901352,
#   'realTimeWorth': 2232.65,
#   'realTimeRank': 1147,
#   'realTimePosition': 1147,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-80a4aab09c73> in <module>
# ----> 1 data[0]
#
# TypeError: 'method' object is not subscriptable
