# %%
import matplotlib.pyplot as plt
import pandas as pd
#from matplotlib.pyplot import figure

# %%
#figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

# %%
df = pd.read_csv('../data/processed/final.csv')

# %%
plt.style.use('seaborn')

# %%
#grouping by 'Country' and 'GDP' sum the column 'worth in Billion' and call it 'Total richest'
bycountry = df.groupby(['Country','GDP in Billions USD'])['worth in Billion USD'].sum().reset_index(name = 'Total richest worth')

# %%
bycountry['% of GDP own by the richest'] = round(bycountry['Total richest worth'] / bycountry['GDP in Billions USD']*100)

# %%
bycountry.sort_values(by=['% of GDP own by the richest'], inplace=True, ascending=False)

# %%
x = bycountry['Country'].head(10)
y = bycountry['% of GDP own by the richest'].head(10)

# %%
x
# Out:
# 15        Hong Kong
# 5             Chile
# 36           Russia
# 42         Thailand
# 19           Israel
# 39           Sweden
# 40      Switzerland
# 38            Spain
# 46    United States
# 37        Singapore
# Name: Country, dtype: object

# %%
bycountry.plot(x = 'Country', y = '% of GDP own by the richest', kind = 'barh', figsize=(6,10))
fig1 = plt.gcf()

# %%
fig1.savefig('../data/results/image.png')
